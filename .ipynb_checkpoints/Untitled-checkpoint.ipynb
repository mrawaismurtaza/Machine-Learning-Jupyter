# %%
from numpy import *

# %%
y , x = mgrid[0:6, 0:3]
x
# Out:
# array([[0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2]])

# %%
y
# Out:
# array([[0, 0, 0],
#        [1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3],
#        [4, 4, 4],
#        [5, 5, 5]])

# %%
random.rand(3,1)
# Out:
# array([[0.38259339],
#        [0.53679918],
#        [0.88410004]])

# %%
random.randn(3,3)
# Out:
# array([[-1.217687  , -1.30357238,  0.04033167],
#        [-0.61681631, -0.08286453,  0.43692828],
#        [ 0.65384082,  0.02156215,  0.41064612]])

# %%
random.randn(1000,1000)
# Out:
# array([[-0.32295004,  0.23377401, -2.13316716, ..., -0.70247318,
#         -0.50543345, -1.56804538],
#        [-1.00812686, -1.41699346,  0.29634512, ..., -1.61182347,
#          1.13468173, -0.30323712],
#        [ 0.53655495, -0.20912327, -0.08025124, ...,  0.15616602,
#         -1.59547083,  0.34538135],
#        ...,
#        [ 0.42698854, -0.58743682,  0.19065259, ..., -0.16508813,
#         -0.67974877, -0.08549753],
#        [ 0.94425216,  0.36188675,  1.39261514, ..., -1.2096486 ,
#         -1.51246237,  0.19886731],
#        [ 0.04173248, -2.30622125,  0.63733161, ..., -0.13846587,
#         -0.15308123, -0.35376556]])

# %%
data = genfromtxt(r'C:\Users\star\Documents\Python Start Projects\Python Libraries\stockholm_td_adj.dat')

# %%
print(data[:5])
# Out:
# [[ 1.80e+03  1.00e+00  1.00e+00 -6.10e+00 -6.10e+00 -6.10e+00  1.00e+00]
#  [ 1.80e+03  1.00e+00  2.00e+00 -1.54e+01 -1.54e+01 -1.54e+01  1.00e+00]
#  [ 1.80e+03  1.00e+00  3.00e+00 -1.50e+01 -1.50e+01 -1.50e+01  1.00e+00]
#  [ 1.80e+03  1.00e+00  4.00e+00 -1.93e+01 -1.93e+01 -1.93e+01  1.00e+00]
#  [ 1.80e+03  1.00e+00  5.00e+00 -1.68e+01 -1.68e+01 -1.68e+01  1.00e+00]]

# %%
import matplotlib.pyplot as plt

# %%
new = data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5]

# %%
new
# Out:
# (array([1800.08607306, 1800.08881279, 1800.09155251, ..., 2012.07945205,
#         2012.08219178, 2012.08493151]),
#  array([ -6.1, -15.4, -15. , ...,   4.2,  -0.1,  -3.3]))

# %%
plt.figure(figsize=(14, 4))
plt.plot(data[:,0] + data[:,1]/12.0 + data[:,2]/365, data[:,5])
plt.axis('tight')
plt.title('Temperatures in Stockholm')
plt.xlabel('Year')
plt.ylabel('Temperature (C)')
plt.show()
